# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import scipy.io as sio
from models import DIP_CASSI
import os
from optics.cassi import *
# load a mat file

cube = tf.image.resize(sio.loadmat(os.path.join('examples', 'data', 'spectral_image.mat'))['img'],[64,64])  # (M, N, L)

ca = np.random.rand(1, cube.shape[0], cube.shape[1], 1)  # custom ca (1, M, N, 1)

mode = 'base'
cassi = CASSI(mode, initial_ca=ca)
cassi.build(ca.shape[1:])

cube_tf = tf.convert_to_tensor(cube)[None]  # None add a new dimension
y = cassi(cube_tf, type_calculation="forward")
network_args = {'features': [28,32,14],'reduce_spatial':False,'out_channels':cube_tf.shape[-1],}
model = DIP_CASSI(input_shape=cube.shape,recon='autoencoder',initilization='random',network_args=network_args,optical_layer=cassi)


model.compile(optimizer='adam',loss='mean_squared_error')

# %%
model.fit(x=y,y=y,epochs=10000)



recon = model(y,False)

fig, axs = plt.subplots(1, 2, figsize=(10, 5))  # 1 row, 2 columns

# Display the first image in the first subplot
axs[0].imshow(np.squeeze(cube_tf[:,:,:,0]))
axs[0].set_title('GT')

# Display the second image in the second subplot
axs[1].imshow(np.squeeze(recon[:,:,:,0]))
axs[1].set_title('Recon')

# Optionally, you can hide the axis labels and ticks
axs[0].axis('off')
axs[1].axis('off')

# Show the figure
plt.show()
# Out:
# Epoch 1/10000
# 1/1 [==============================] - 11s 11s/step - loss: 1.0023
# Epoch 2/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7740
# Epoch 3/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3612
# Epoch 4/10000
# 1/1 [==============================] - 4s 4s/step - loss: 1.3906
# Epoch 5/10000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3653
# Epoch 6/10000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3642
# Epoch 7/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4860
# Epoch 8/10000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5511
# Epoch 9/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5588
# Epoch 10/10000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5222
# Epoch 11/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4413
# Epoch 12/10000
# ...
